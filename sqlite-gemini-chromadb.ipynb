# %% [markdown]
# # Generating SQL for SQLite using Google Gemini, ChromaDB
# This notebook runs through the process of using the `vanna` Python package to generate SQL using AI (RAG + LLMs) including connecting to a database and training. If you're not ready to train on your own database, you can still try it using a sample [SQLite database](app.md).

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Which LLM do you want to use?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../sqlite-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">OpenAI via Vanna.AI (Recommended)</div>
#         <small class="w-full">Use Vanna.AI for free to generate your queries</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-openai-standard-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">OpenAI</div>
#         <small class="w-full">Use OpenAI with your own API key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-openai-azure-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Azure OpenAI</div>
#         <small class="w-full">If you have OpenAI models deployed on Azure</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-anthropic-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Anthropic</div>
#         <small class="w-full">Use Anthropics Claude with your Anthropic API Key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-ollama-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Ollama</div>
#         <small class="w-full">Use Ollama locally for free. Requires additional setup.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> Google Gemini</div>
#         <small class="w-full">Use Google Gemini with your Gemini or Vertex API Key</small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../sqlite-mistral-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Mistral via Mistral API</div>
#         <small class="w-full">If you have a Mistral API key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-other-llm-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other LLM</div>
#         <small class="w-full">If you have a different LLM model</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Where do you want to store the 'training' data?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../sqlite-gemini-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Vanna Hosted Vector DB (Recommended)</div>
#         <small class="w-full">Use Vanna.AIs hosted vector database (pgvector) for free. This is usable across machines with no additional setup.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> ChromaDB</div>
#         <small class="w-full">Use ChromaDBs open-source vector database for free locally. No additional setup is necessary -- all database files will be created and stored locally.</small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../sqlite-gemini-qdrant/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Qdrant</div>
#         <small class="w-full">Use Qdrants open-source vector database</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-gemini-marqo/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Marqo</div>
#         <small class="w-full">Use Marqo locally for free. Requires additional setup. Or use their hosted option.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-gemini-other-vectordb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other VectorDB</div>
#         <small class="w-full">Use any other vector database. Requires additional setup.</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %% [markdown]
# ## Setup

# %%
# %pip install 'vanna[chromadb,gemini]'
# Out:
# Collecting vanna[chromadb,gemini]
#   Downloading vanna-0.7.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (2.32.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (0.9.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (2.2.2)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (0.5.2)
# Collecting kaleido (from vanna[chromadb,gemini])
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (3.0.3)
# Collecting flask-sock (from vanna[chromadb,gemini])
#   Downloading flask_sock-0.7.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting flasgger (from vanna[chromadb,gemini])
#   Downloading flasgger-0.9.7.1.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (2.0.36)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (from vanna[chromadb,gemini]) (0.8.3)
# Collecting chromadb (from vanna[chromadb,gemini])
#   Downloading chromadb-0.5.20-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb->vanna[chromadb,gemini])
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb->vanna[chromadb,gemini])
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb->vanna[chromadb,gemini])
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,gemini])
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb->vanna[chromadb,gemini])
#   Downloading posthog-3.7.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb->vanna[chromadb,gemini])
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (1.28.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (0.20.3)
# Collecting pypika>=0.48.9 (from chromadb->vanna[chromadb,gemini])
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (4.66.6)
# Collecting overrides>=7.3.1 (from chromadb->vanna[chromadb,gemini])
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (1.68.0)
# Collecting bcrypt>=4.0.1 (from chromadb->vanna[chromadb,gemini])
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (0.13.0)
# Collecting kubernetes>=28.1.0 (from chromadb->vanna[chromadb,gemini])
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb->vanna[chromadb,gemini])
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->vanna[chromadb,gemini]) (13.9.4)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from flasgger->vanna[chromadb,gemini]) (4.23.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.10/dist-packages (from flasgger->vanna[chromadb,gemini]) (3.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from flasgger->vanna[chromadb,gemini]) (1.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flasgger->vanna[chromadb,gemini]) (24.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from flask->vanna[chromadb,gemini]) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask->vanna[chromadb,gemini]) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from flask->vanna[chromadb,gemini]) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask->vanna[chromadb,gemini]) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from flask->vanna[chromadb,gemini]) (1.9.0)
# Collecting simple-websocket>=0.5.1 (from flask-sock->vanna[chromadb,gemini])
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai->vanna[chromadb,gemini]) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai->vanna[chromadb,gemini]) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai->vanna[chromadb,gemini]) (2.151.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai->vanna[chromadb,gemini]) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai->vanna[chromadb,gemini]) (4.25.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai->vanna[chromadb,gemini]) (1.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vanna[chromadb,gemini]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vanna[chromadb,gemini]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->vanna[chromadb,gemini]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vanna[chromadb,gemini]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vanna[chromadb,gemini]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vanna[chromadb,gemini]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vanna[chromadb,gemini]) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->vanna[chromadb,gemini]) (3.1.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->vanna[chromadb,gemini])
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb->vanna[chromadb,gemini]) (2.1.0)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb->vanna[chromadb,gemini])
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai->vanna[chromadb,gemini]) (1.66.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai->vanna[chromadb,gemini]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai->vanna[chromadb,gemini]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai->vanna[chromadb,gemini]) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb->vanna[chromadb,gemini]) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb->vanna[chromadb,gemini]) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb->vanna[chromadb,gemini]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->vanna[chromadb,gemini]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask->vanna[chromadb,gemini]) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (0.21.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,gemini]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,gemini]) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,gemini]) (3.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb->vanna[chromadb,gemini])
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,gemini])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,gemini]) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,gemini]) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,gemini]) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,gemini]) (8.5.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_proto-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from google-generativeai->vanna[chromadb,gemini])
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,gemini]) (0.49b2)
# Collecting opentelemetry-util-http==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,gemini])
#   Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,gemini]) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,gemini])
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb->vanna[chromadb,gemini])
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb->vanna[chromadb,gemini])
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb->vanna[chromadb,gemini]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb->vanna[chromadb,gemini]) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb->vanna[chromadb,gemini]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb->vanna[chromadb,gemini]) (2.18.0)
# Collecting wsproto (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,gemini])
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb->vanna[chromadb,gemini]) (0.26.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb->vanna[chromadb,gemini]) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,gemini])
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,gemini])
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,gemini])
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,gemini])
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,gemini])
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->vanna[chromadb,gemini]) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,gemini]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,gemini]) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,gemini]) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->vanna[chromadb,gemini]) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->vanna[chromadb,gemini]) (0.6.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb->vanna[chromadb,gemini]) (1.2.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,gemini])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb->vanna[chromadb,gemini]) (1.3.0)
# Downloading chromadb-0.5.20-py3-none-any.whl (617 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.9/617.9 kB 33.1 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.4 MB/s eta 0:00:00
# Downloading flask_sock-0.7.0-py3-none-any.whl (4.0 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.8 MB/s eta 0:00:00
# Downloading vanna-0.7.5-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.4/202.4 kB 13.6 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 19.4 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.7 MB/s eta 0:00:00
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 55.5 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 71.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.5 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl (6.9 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.7.2-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.6 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 20.9 MB/s eta 0:00:00
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.8 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 27.8 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.9 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 69.9 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 27.3 MB/s eta 0:00:00
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 13.0 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: flasgger, pypika
#   Building wheel for flasgger (setup.py) ... done
#   Created wheel for flasgger: filename=flasgger-0.9.7.1-py2.py3-none-any.whl size=3865184 sha256=e58fa8d2dd33e4d233692d923697a2792de076828587854175651adb5be58d2c
#   Stored in directory: /root/.cache/pip/wheels/92/c0/ec/a7935834b3205c0c0acbd4ba52b9c8215835984fe168374262
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=89f472738501ebc3745afdc2fa3ebbf8c11fc6ef884b5e6e125573cf6dc1d14b
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built flasgger pypika
# Installing collected packages: pypika, monotonic, kaleido, durationpy, wsproto, websockets, uvloop, uvicorn, python-dotenv, pyproject_hooks, protobuf, overrides, opentelemetry-util-http, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, simple-websocket, posthog, opentelemetry-proto, coloredlogs, build, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, flask-sock, fastapi, opentelemetry-instrumentation, flasgger, vanna, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.20 coloredlogs-15.0.1 durationpy-0.9 fastapi-0.115.5 flasgger-0.9.7.1 flask-sock-0.7.0 httptools-0.6.4 humanfriendly-10.0 kaleido-0.2.1 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 onnxruntime-1.20.1 opentelemetry-exporter-otlp-proto-common-1.28.2 opentelemetry-exporter-otlp-proto-grpc-1.28.2 opentelemetry-instrumentation-0.49b2 opentelemetry-instrumentation-asgi-0.49b2 opentelemetry-instrumentation-fastapi-0.49b2 opentelemetry-proto-1.28.2 opentelemetry-util-http-0.49b2 overrides-7.7.0 posthog-3.7.2 protobuf-5.28.3 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 simple-websocket-1.1.0 starlette-0.41.3 uvicorn-0.32.1 uvloop-0.21.0 vanna-0.7.5 watchfiles-0.24.0 websockets-14.1 wsproto-1.2.0

# %%
from vanna.chromadb import ChromaDB_VectorStore
from vanna.google import GoogleGeminiChat

# %%
class MyVanna(ChromaDB_VectorStore, GoogleGeminiChat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        GoogleGeminiChat.__init__(self, config={'api_key': 'AIzaSyCeXu7ZESrDVHmrgMnOXJ6efM6S7GVVOY0', 'model': 'gemini-1.5-flash'})

vn = MyVanna()

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Which database do you want to query?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../postgres-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Postgres</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mssql-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Microsoft SQL Server</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">MySQL</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../duckdb-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">DuckDB</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../snowflake-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Snowflake</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../bigquery-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">BigQuery</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> SQLite</div>
#         <small class="w-full"></small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../oracle-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Oracle</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../other-database-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other Database</div>
#         <small class="w-full">Use Vanna to generate queries for any SQL database</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %%
# vn.connect_to_sqlite('/content/my_database.db')

# تثبيت مكتبة gdown إذا لم تكن مثبتة
# !pip install gdown

# تنزيل الملف من Google Drive باستخدام ID
file_id = "1AQ_tpmuc57op9ooC7t9q1UoAwZlIvBAW"
destination = "/content/my_database.db"  # المسار المحلي لحفظ الملف
# !gdown --id $file_id -O $destination

# الاتصال بقاعدة بيانات SQLite
vn.connect_to_sqlite(destination)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1AQ_tpmuc57op9ooC7t9q1UoAwZlIvBAW
# To: /content/my_database.db
# 100% 71.0M/71.0M [00:00<00:00, 74.4MB/s]

# %%
cursor

# %% [markdown]
# ## Training
# You only need to train once. Do not train again unless you want to add more training data.

# %%
df_ddl = vn.run_sql("SELECT type, sql FROM sqlite_master WHERE sql is not null")

# تدريب النموذج باستخدام DDL المستخرج
for ddl in df_ddl['sql'].to_list():
    vn.train(ddl=ddl)
# Out:
# Adding ddl: CREATE TABLE "final_data" (
# "index" INTEGER,
#   "date" TEXT,
#   "user" TEXT,
#   "total_login_count" INTEGER,
#   "after_hours_login_count" INTEGER,
#   "distinct_pc_accessed_count" INTEGER,
#   "Average_login_duration" REAL,
#   "Standard_deviation_of_login_duration" REAL,
#   "valid_session_count" INTEGER,
#   "login_own_pc_count" INTEGER,
#   "login_supervisor_pc_count" INTEGER,
#   "login_other_pc_count" INTEGER,
#   "after_hours_distinct_pc_count" INTEGER,
#   "avg_after_hours_session_duration" REAL,
#   "total_logout_count" INTEGER,
#   "after_hours_login_flag" INTEGER,
#   "login_own_pc_flag" INTEGER,
#   "login_supervisor_pc_flag" INTEGER,
#   "login_other_pc_flag" INTEGER,
#   "daily_thumb_drive_count" REAL,
#   "daily_thumb_drive_count_median" REAL,
#   "exceeds_median" REAL,
#   "anomaly_based_on_zscore" REAL,
#   "device_connect_count" REAL,
#   "device_disconnect_count" REAL,
#   "connect_to_disconnect_ratio" REAL,
#   "off_hours_device_usage_count" REAL,
#   "work_hours_device_usage_count" REAL,
#   "days_since_last_usage" REAL,
#   "no_prior_usage_flag" INTEGER,
#   "first_time_usage_flag" INTEGER,
#   "atypical_device_user_flag" REAL,
#   "keylogger_sites_visit_count" REAL,
#   "wikileaks_visit_count" REAL,
#   "job_sites_visit_count" REAL,
#   "unique_recipients_count" REAL,
#   "total_recipients_count" REAL,
#   "internal_to_internal_count" REAL,
#   "internal_to_external_count" REAL,
#   "external_to_internal_count" REAL,
#   "external_to_external_count" REAL,
#   "total_internal_recipients" REAL,
#   "total_external_recipients" REAL,
#   "total_emails_sent" REAL,
#   "total_attachments" REAL,
#   "total_after_hours_emails" REAL,
#   "is_exe" REAL,
#   "files_copies_count" REAL,
#   "exceeds_normal" REAL,
#   "O" INTEGER,
#   "C" INTEGER,
#   "E" INTEGER,
#   "A" INTEGER,
#   "N" INTEGER,
#   "role" TEXT,
#   "department" TEXT,
#   "functional_unit" TEXT,
#   "team" TEXT,
#   "late_work_arrival_probability" REAL,
#   "high_connection_probability" REAL,
#   "user_engagement_risk_score" REAL
# )
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: ddd22841-8510-5b39-8dd5-c43437a106c6-ddl
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: ddd22841-8510-5b39-8dd5-c43437a106c6-ddl
# Adding ddl: CREATE INDEX "ix_final_data_index"ON "final_data" ("index")
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15b739e0-3768-55cf-9817-bb47974bd649-ddl
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 15b739e0-3768-55cf-9817-bb47974bd649-ddl

# %%
# The following are methods for adding training data. Make sure you modify the examples to match your database.

# DDL statements are powerful because they specify table names, colume names, types, and potentially relationships
vn.train(ddl="""
    CREATE TABLE IF NOT EXISTS my-table (
        id INT PRIMARY KEY,
        name VARCHAR(100),
        age INT
    )
""")

# Sometimes you may want to add documentation about your business terminology or definitions.
vn.train(documentation="Our business defines OTIF score as the percentage of orders that are delivered on time and in full")

# You can also add SQL queries to your training data. This is useful if you have some queries already laying around. You can just copy and paste those from your editor to begin generating new SQL.
vn.train(sql="SELECT * FROM my-table WHERE name = 'John Doe'")
# Out:
# Adding ddl:
#     CREATE TABLE IF NOT EXISTS my-table (
#         id INT PRIMARY KEY,
#         name VARCHAR(100),
#         age INT
#     )
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4aafa9de-6443-5409-86f9-5d581327d6a0-ddl
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 4aafa9de-6443-5409-86f9-5d581327d6a0-ddl
# Adding documentation....
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 51cf1d6d-7637-5b87-b9e7-31c577fbde59-doc
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 51cf1d6d-7637-5b87-b9e7-31c577fbde59-doc
# Question generated with sql: What are John Doe's details?
#
# Adding SQL...
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 9112f7c2-8f87-55ff-8e5b-313dcda0f465-sql
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9112f7c2-8f87-55ff-8e5b-313dcda0f465-sql
# '9112f7c2-8f87-55ff-8e5b-313dcda0f465-sql'

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#                                          id  \
# 0  9112f7c2-8f87-55ff-8e5b-313dcda0f465-sql
# 1  c9068ce5-3ae1-5b6b-a8ad-3213c7358b6b-sql
# 2  a168beba-4c56-5e95-a0b9-07fdaa290a67-sql
# 0  4aafa9de-6443-5409-86f9-5d581327d6a0-ddl
# 1  ddd22841-8510-5b39-8dd5-c43437a106c6-ddl
# 2  15b739e0-3768-55cf-9817-bb47974bd649-ddl
# 0  51cf1d6d-7637-5b87-b9e7-31c577fbde59-doc
#
#                                question  \
# 0        What are John Doe's details?\n
# 1  What are the details for John Doe?\n
# 2           how many users in database?
# 0                                  None
# 1                                  None
# 2                                  None
# 0                                  None
#
#                                              content training_data_type
# 0     SELECT * FROM my-table WHERE name = 'John Doe'                sql
# 1     SELECT * FROM my-table WHERE name = 'John Doe'                sql
# 2       SELECT COUNT(DISTINCT user) FROM final_data;                sql
# 0  \n    CREATE TABLE IF NOT EXISTS my-table (\n ...                ddl
# 1  CREATE TABLE "final_data" (\n"index" INTEGER,\...                ddl
# 2  CREATE INDEX "ix_final_data_index"ON "final_da...                ddl
# 0  Our business defines OTIF score as the percent...      documentation

# %%
# You can remove training data if there's obsolete/incorrect information.
vn.remove_training_data(id='1-ddl')
# Out:
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Delete of nonexisting embedding ID: 1-ddl
# WARNING:chromadb.segment.impl.metadata.sqlite:Delete of nonexisting embedding ID: 1-ddl
# True

# %% [markdown]
# ## Asking the AI
# Whenever you ask a new question, it will find the 10 most relevant pieces of training data and use it as part of the LLM prompt to generate the SQL.

# %%
vn.ask(question='how many users in database?')
# Out:
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# SQL Prompt: ['You are a SQLite expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Tables \nCREATE TABLE "final_data" (\n"index" INTEGER,\n  "date" TEXT,\n  "user" TEXT,\n  "total_login_count" INTEGER,\n  "after_hours_login_count" INTEGER,\n  "distinct_pc_accessed_count" INTEGER,\n  "Average_login_duration" REAL,\n  "Standard_deviation_of_login_duration" REAL,\n  "valid_session_count" INTEGER,\n  "login_own_pc_count" INTEGER,\n  "login_supervisor_pc_count" INTEGER,\n  "login_other_pc_count" INTEGER,\n  "after_hours_distinct_pc_count" INTEGER,\n  "avg_after_hours_session_duration" REAL,\n  "total_logout_count" INTEGER,\n  "after_hours_login_flag" INTEGER,\n  "login_own_pc_flag" INTEGER,\n  "login_supervisor_pc_flag" INTEGER,\n  "login_other_pc_flag" INTEGER,\n  "daily_thumb_drive_count" REAL,\n  "daily_thumb_drive_count_median" REAL,\n  "exceeds_median" REAL,\n  "anomaly_based_on_zscore" REAL,\n  "device_connect_count" REAL,\n  "device_disconnect_count" REAL,\n  "connect_to_disconnect_ratio" REAL,\n  "off_hours_device_usage_count" REAL,\n  "work_hours_device_usage_count" REAL,\n  "days_since_last_usage" REAL,\n  "no_prior_usage_flag" INTEGER,\n  "first_time_usage_flag" INTEGER,\n  "atypical_device_user_flag" REAL,\n  "keylogger_sites_visit_count" REAL,\n  "wikileaks_visit_count" REAL,\n  "job_sites_visit_count" REAL,\n  "unique_recipients_count" REAL,\n  "total_recipients_count" REAL,\n  "internal_to_internal_count" REAL,\n  "internal_to_external_count" REAL,\n  "external_to_internal_count" REAL,\n  "external_to_external_count" REAL,\n  "total_internal_recipients" REAL,\n  "total_external_recipients" REAL,\n  "total_emails_sent" REAL,\n  "total_attachments" REAL,\n  "total_after_hours_emails" REAL,\n  "is_exe" REAL,\n  "files_copies_count" REAL,\n  "exceeds_normal" REAL,\n  "O" INTEGER,\n  "C" INTEGER,\n  "E" INTEGER,\n  "A" INTEGER,\n  "N" INTEGER,\n  "role" TEXT,\n  "department" TEXT,\n  "functional_unit" TEXT,\n  "team" TEXT,\n  "late_work_arrival_probability" REAL,\n  "high_connection_probability" REAL,\n  "user_engagement_risk_score" REAL\n)\n\n\n    CREATE TABLE IF NOT EXISTS my-table (\n        id INT PRIMARY KEY,\n        name VARCHAR(100),\n        age INT\n    )\n\n\nCREATE INDEX "ix_final_data_index"ON "final_data" ("index")\n\n\n===Additional Context \n\nOur business defines OTIF score as the percentage of orders that are delivered on time and in full\n\n===Response Guidelines \n1. If the provided context is sufficient, please generate a valid SQL query without any explanations for the question. \n2. If the provided context is almost sufficient but requires knowledge of a specific string in a particular column, please generate an intermediate SQL query to find the distinct strings in that column. Prepend the query with a comment saying intermediate_sql \n3. If the provided context is insufficient, please explain why it can\'t be generated. \n4. Please use the most relevant table(s). \n5. If the question has been asked and answered before, please repeat the answer exactly as it was given before. \n6. Ensure that the output SQL is SQLite-compliant and executable, and free of syntax errors. \n', 'how many users in database?', 'SELECT COUNT(DISTINCT user) FROM final_data;', 'What are the details for John Doe?\n', "SELECT * FROM my-table WHERE name = 'John Doe'", "What are John Doe's details?\n", "SELECT * FROM my-table WHERE name = 'John Doe'", 'how many users in database?']
# LLM Response: SELECT COUNT(DISTINCT user) FROM final_data;
#
# Extracted SQL: SELECT COUNT(DISTINCT user) FROM final_data;
# SELECT COUNT(DISTINCT user) FROM final_data;
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: a168beba-4c56-5e95-a0b9-07fdaa290a67-sql
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: a168beba-4c56-5e95-a0b9-07fdaa290a67-sql
#    COUNT(DISTINCT user)
# 0                  1000
# ('SELECT COUNT(DISTINCT user) FROM final_data;',
#     COUNT(DISTINCT user)
#  0                  1000,
#  Figure({
#      'data': [{'mode': 'number', 'title': {'text': 'Number of Users'}, 'type': 'indicator', 'value': 1000}],
#      'layout': {'template': '...'}
#  }))

# %% [markdown]
# ## Launch the User Interface
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn,allow_llm_to_see_data=True)
app.run()
# Out:
# Google Colab doesn't support running websocket servers. Disabling debug mode.
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.
# Your app is running at:
# https://dsbf072lfr-496ff2e9c6d22116-8084-colab.googleusercontent.com/
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: off
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# SQL Prompt: ['You are a SQLite expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Tables \nCREATE TABLE "final_data" (\n"index" INTEGER,\n  "date" TEXT,\n  "user" TEXT,\n  "total_login_count" INTEGER,\n  "after_hours_login_count" INTEGER,\n  "distinct_pc_accessed_count" INTEGER,\n  "Average_login_duration" REAL,\n  "Standard_deviation_of_login_duration" REAL,\n  "valid_session_count" INTEGER,\n  "login_own_pc_count" INTEGER,\n  "login_supervisor_pc_count" INTEGER,\n  "login_other_pc_count" INTEGER,\n  "after_hours_distinct_pc_count" INTEGER,\n  "avg_after_hours_session_duration" REAL,\n  "total_logout_count" INTEGER,\n  "after_hours_login_flag" INTEGER,\n  "login_own_pc_flag" INTEGER,\n  "login_supervisor_pc_flag" INTEGER,\n  "login_other_pc_flag" INTEGER,\n  "daily_thumb_drive_count" REAL,\n  "daily_thumb_drive_count_median" REAL,\n  "exceeds_median" REAL,\n  "anomaly_based_on_zscore" REAL,\n  "device_connect_count" REAL,\n  "device_disconnect_count" REAL,\n  "connect_to_disconnect_ratio" REAL,\n  "off_hours_device_usage_count" REAL,\n  "work_hours_device_usage_count" REAL,\n  "days_since_last_usage" REAL,\n  "no_prior_usage_flag" INTEGER,\n  "first_time_usage_flag" INTEGER,\n  "atypical_device_user_flag" REAL,\n  "keylogger_sites_visit_count" REAL,\n  "wikileaks_visit_count" REAL,\n  "job_sites_visit_count" REAL,\n  "unique_recipients_count" REAL,\n  "total_recipients_count" REAL,\n  "internal_to_internal_count" REAL,\n  "internal_to_external_count" REAL,\n  "external_to_internal_count" REAL,\n  "external_to_external_count" REAL,\n  "total_internal_recipients" REAL,\n  "total_external_recipients" REAL,\n  "total_emails_sent" REAL,\n  "total_attachments" REAL,\n  "total_after_hours_emails" REAL,\n  "is_exe" REAL,\n  "files_copies_count" REAL,\n  "exceeds_normal" REAL,\n  "O" INTEGER,\n  "C" INTEGER,\n  "E" INTEGER,\n  "A" INTEGER,\n  "N" INTEGER,\n  "role" TEXT,\n  "department" TEXT,\n  "functional_unit" TEXT,\n  "team" TEXT,\n  "late_work_arrival_probability" REAL,\n  "high_connection_probability" REAL,\n  "user_engagement_risk_score" REAL\n)\n\n\n    CREATE TABLE IF NOT EXISTS my-table (\n        id INT PRIMARY KEY,\n        name VARCHAR(100),\n        age INT\n    )\n\n\nCREATE INDEX "ix_final_data_index"ON "final_data" ("index")\n\n\n===Additional Context \n\nOur business defines OTIF score as the percentage of orders that are delivered on time and in full\n\n===Response Guidelines \n1. If the provided context is sufficient, please generate a valid SQL query without any explanations for the question. \n2. If the provided context is almost sufficient but requires knowledge of a specific string in a particular column, please generate an intermediate SQL query to find the distinct strings in that column. Prepend the query with a comment saying intermediate_sql \n3. If the provided context is insufficient, please explain why it can\'t be generated. \n4. Please use the most relevant table(s). \n5. If the question has been asked and answered before, please repeat the answer exactly as it was given before. \n6. Ensure that the output SQL is SQLite-compliant and executable, and free of syntax errors. \n', 'how many users in database?', 'SELECT COUNT(DISTINCT user) FROM final_data;', 'What are the details for John Doe?\n', "SELECT * FROM my-table WHERE name = 'John Doe'", "What are John Doe's details?\n", "SELECT * FROM my-table WHERE name = 'John Doe'", 'what is the department user AAE0190 ?']
# ERROR:vanna.flask:Exception on /api/v0/generate_sql [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.10/dist-packages/flask/app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "/usr/local/lib/python3.10/dist-packages/vanna/flask/__init__.py", line 138, in decorated
#     return f(*args, user=user, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/vanna/flask/__init__.py", line 335, in generate_sql
#     sql = vn.generate_sql(question=question, allow_llm_to_see_data=self.allow_llm_to_see_data)
#   File "/usr/local/lib/python3.10/dist-packages/vanna/base/base.py", line 136, in generate_sql
#     llm_response = self.submit_prompt(prompt, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/vanna/google/gemini_chat.py", line 46, in submit_prompt
#     response = self.chat_model.generate_content(
#   File "/usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 830, in generate_content
#     response = rpc(
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py", line 76, in error_remapped_callable
#     return callable_(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py", line 847, in __call__
#     raise core_exceptions.from_http_response(response)
# google.api_core.exceptions.InternalServerError: 500 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: TypeError: Failed to fetch
# ERROR:tornado.access:500 POST /v1beta/models/gemini-1.5-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 766.53ms

# %% [markdown]
# ## Next Steps
# Using Vanna via Jupyter notebooks is great for getting started but check out additional customizable interfaces like the
# - [Streamlit app](https://github.com/vanna-ai/vanna-streamlit)
# - [Flask app](https://github.com/vanna-ai/vanna-flask)
# - [Slackbot](https://github.com/vanna-ai/vanna-slack)
